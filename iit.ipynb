# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("vscodeiitcuoff.csv")

# %%
data.head(72)
# Out:
#                                      Institute  \
# 0   Indian Institute of Technology Bhubaneswar
# 1   Indian Institute of Technology Bhubaneswar
# 2   Indian Institute of Technology Bhubaneswar
# 3   Indian Institute of Technology Bhubaneswar
# 4   Indian Institute of Technology Bhubaneswar
# ..                                         ...
# 67  Indian Institute of Technology Bhubaneswar
# 68  Indian Institute of Technology Bhubaneswar
# 69  Indian Institute of Technology Bhubaneswar
# 70  Indian Institute of Technology Bhubaneswar
# 71  Indian Institute of Technology Bhubaneswar
#
#                                 Academic Program Name Seat type  Category  \
# 0   Civil Engineering (4 Years, Bachelor of Techno...        AI      OPEN
# 1   Civil Engineering (4 Years, Bachelor of Techno...        AI      OPEN
# 2   Civil Engineering (4 Years, Bachelor of Techno...        AI       EWS
# 3   Civil Engineering (4 Years, Bachelor of Techno...        AI       EWS
# ...

# %%
nan_rows = data[data.isna().any(axis=1)]

print(nan_rows)
len(nan_rows)
# Out:
# Empty DataFrame
# Columns: [Institute, Academic Program Name, Seat type, Category, Gender, Opening Rank, Closing Rank]
# Index: []
# 0

# %%
data.columns
# Out:
# Index(['Institute', 'Academic Program Name', 'Seat type', 'Category', 'Gender',
#        'Opening Rank', 'Closing Rank'],
#       dtype='object')

# %%
missing_count = data["Closing Rank"].isna().sum()
print(missing_count)
# Out:
# 0

# %%
pd.to_numeric(data["Closing Rank"], errors='coerce').dtypes
# Out:
# dtype('float64')

# %%
category = "SC" 
lower = 1237
upper = 3267
gender = "Gender-Neutral"

data = pd.read_csv("vscodeiitcuoff.csv")

data.head(72)
new_data = data[data["Category"] == category]
new_data["Closing Rank"] = pd.to_numeric(new_data["Closing Rank"], errors='coerce')
new_data["Closing Rank"].dtype
filterd_data = new_data[(new_data["Closing Rank"] > int(lower)) & (new_data["Closing Rank"] < int(upper))]
AI_data = filterd_data[(filterd_data["Seat type"] == "AI") & (filterd_data["Gender"] == gender)]
result_table = AI_data.to_dict(orient='records')       
result_table
# Out:
# C:\Users\matka\AppData\Local\Temp\ipykernel_25292\3506271630.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["Closing Rank"] = pd.to_numeric(new_data["Closing Rank"], errors='coerce')
# [{'Institute': 'Indian Institute of Technology Bhubaneswar',
#   'Academic Program Name': 'Civil Engineering (4 Years, Bachelor of Technology)',
#   'Seat type': 'AI',
#   'Category': 'SC',
#   'Gender': 'Gender-Neutral',
#   'Opening Rank': '2381',
#   'Closing Rank': 2587},
#  {'Institute': 'Indian Institute of Technology Bhubaneswar',
#   'Academic Program Name': 'Electrical Engineering (4 Years, Bachelor of Technology)',
#   'Seat type': 'AI',
#   'Category': 'SC',
#   'Gender': 'Gender-Neutral',
#   'Opening Rank': '1105',
# ...
